# %%
import pandas as pd
import folium
from ast import literal_eval

# %% [markdown]
# # Creating Maps of the Subway System
#
# Here I am using Folium to plot the subway stops on the map of New York City. I have made several versions of this plot including:
# - A basic map of all the stops
# - A map showing all the possible transfer points
# -

# %%
stops = pd.read_csv('../Data/stops_updated.txt',usecols=['stop_id','stop_name','stop_lat','stop_lon','parent_station','lines'])
stops['lines'] = stops['lines'].apply(literal_eval)
ordered_stops = pd.read_csv('../Data/ordered_stops.txt',usecols=['route_id','stop_id','stop_sequence'])

# %%
parent_stops = stops[stops['parent_station'].isnull()].reset_index(drop=True)

# %%
ordered_stops['route_dir_id'] = ordered_stops['route_id'] + ordered_stops['stop_id'].str[-1]
ordered_stops = ordered_stops.merge(stops[['stop_id','stop_name','stop_lat','stop_lon','parent_station']],on='stop_id').sort_values(['route_dir_id','stop_sequence']).reset_index(drop=True)

# %%
colors = {'1N':'red','2N':'red','3N':'red','4N':'green','5N':'green','6N':'green',
          '7N':'purple','A1N':'blue','A2N':'blue','CN':'blue','EN':'blue',
          'BN':'orange','DN':'orange','FN':'orange','MN':'orange',
          'FSN':'grey','HN':'grey','LN':'grey','GSN':'grey','GN':'lightgreen',
          'JN':'brown','ZN':'brown','NN':'yellow','QN':'yellow','RN':'yellow','SIN':'lightblue'}

# %% [markdown]
# To plot each line correctly, I did some manual labor to delete the duplicate stops to make sure the stops were connected in the correct order. This work is not shown in the notebook, but the output is saved to a file.

# %%
inds_2 = inds_2a.append(inds_2b).append(inds_2c).append(inds_2d).append(inds_2e)

# %%
inds = inds_1.append(inds_2).append(inds_3).append(inds_4).append(inds_5).append(inds_6).append(inds_7).append(inds_8).append(inds_9).append(inds_10)

# %%
#ploting_data = ordered_stops.loc[inds].reset_index(drop=True)
#ploting_data.to_csv('../Data/stops_for_plot.csv')
ploting_data = pd.read_csv('../Data/stops_for_plot.csv')

# %%
map1 = folium.Map(location=[40.7528, -73.92],zoom_start=12,tiles='Stamen Terrain')

for i in xrange(len(ploting_data)):
    folium.RegularPolygonMarker(location=[ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']], 
                                popup=ploting_data.loc[i]['stop_name'],number_of_sides=4, radius=2,
                                color=colors[ploting_data.loc[i]['route_dir_id']],
                                fill_color=colors[ploting_data.loc[i]['route_dir_id']]).add_to(map1)
for i in xrange(len(ploting_data)-1):
    if ploting_data.loc[i]['route_dir_id']==ploting_data.loc[i+1]['route_dir_id'] and ploting_data.loc[i]['stop_sequence']==ploting_data.loc[i+1]['stop_sequence']-1:
        folium.PolyLine([(ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']),
                         (ploting_data.loc[i+1]['stop_lat'],ploting_data.loc[i+1]['stop_lon'])],
                        opacity=1,color=colors[ploting_data.loc[i]['route_dir_id']],weight=2).add_to(map1)
map1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-71671bf47e5d> in <module>()
#       5                                 popup=ploting_data.loc[i]['stop_name'],number_of_sides=4, radius=2,
#       6                                 color=colors[ploting_data.loc[i]['route_dir_id']],
# ----> 7                                 fill_color=colors[ploting_data.loc[i]['route_dir_id']]).add_to(map1)
#       8 for i in xrange(len(ploting_data)-1):
#       9     if ploting_data.loc[i]['route_dir_id']==ploting_data.loc[i+1]['route_dir_id'] and ploting_data.loc[i]['stop_sequence']==ploting_data.loc[i+1]['stop_sequence']-1:
#
# /opt/conda/lib/python2.7/site-packages/folium/features.pyc in __init__(self, location, color, opacity, weight, fill_color, fill_opacity, number_of_sides, rotation, radius, popup)
#     120                  fill_color='blue', fill_opacity=1,
#     121                  number_of_sides=4, rotation=0, radius=15, popup=None):
# --> 122         super(RegularPolygonMarker, self).__init__(location, popup=popup)
#     123         self._name = 'RegularPolygonMarker'
#     124         self.color = color
#
# /opt/conda/lib/python2.7/site-packages/folium/map.pyc in __init__(self, location, popup, icon)
#     468             self.add_children(icon)
#     469         if isinstance(popup, text_type) or isinstance(popup, binary_type):
# --> 470             self.add_children(Popup(popup))
#     471         elif popup is not None:
#     472             self.add_children(popup)
#
# /opt/conda/lib/python2.7/site-packages/folium/map.pyc in __init__(self, html, max_width)
#     517             self.html.add_children(html)
#     518         elif isinstance(html, text_type) or isinstance(html, binary_type):
# --> 519             self.html.add_children(Html(text_type(html)))
#     520
#     521         self.max_width = max_width
#
# /opt/conda/lib/python2.7/site-packages/folium/element.pyc in __init__(self, data, width, height)
#     438
#     439     def __init__(self, data, width="100%", height="100%"):
# --> 440         super(Html, self).__init__()
#     441         self._name = 'Html'
#     442         self.data = data
#
# /opt/conda/lib/python2.7/site-packages/folium/element.pyc in __init__(self, template, template_name)
#      48             {{element.render(**kwargs)}}
#      49         {% endfor %}
# ---> 50         """)
#      51
#      52     def get_name(self):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/environment.pyc in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape)
#     924             frozenset(extensions), optimized, undefined, finalize, autoescape,
#     925             None, 0, False, None)
# --> 926         return env.from_string(source, template_class=cls)
#     927
#     928     @classmethod
#
# /opt/conda/lib/python2.7/site-packages/jinja2/environment.pyc in from_string(self, source, globals, template_class)
#     860         globals = self.make_globals(globals)
#     861         cls = template_class or self.template_class
# --> 862         return cls.from_code(self, self.compile(source), globals, None)
#     863
#     864     def make_globals(self, d):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/environment.pyc in compile(self, source, name, filename, raw, defer_init)
#     549             if isinstance(source, string_types):
#     550                 source_hint = source
# --> 551                 source = self._parse(source, name, filename)
#     552             if self.optimized:
#     553                 source = optimize(source, self)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/environment.pyc in _parse(self, source, name, filename)
#     468     def _parse(self, source, name, filename):
#     469         """Internal parsing function used by `parse` and `compile`."""
# --> 470         return Parser(self, source, name, encode_filename(filename)).parse()
#     471
#     472     def lex(self, source, name=None, filename=None):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse(self)
#     895     def parse(self):
#     896         """Parse the whole template into a `Template` node."""
# --> 897         result = nodes.Template(self.subparse(), lineno=1)
#     898         result.set_environment(self.environment)
#     899         return result
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in subparse(self, end_tokens)
#     877                        self.stream.current.test_any(*end_tokens):
#     878                         return body
# --> 879                     rv = self.parse_statement()
#     880                     if isinstance(rv, list):
#     881                         body.extend(rv)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_statement(self)
#     119         try:
#     120             if token.value in _statement_keywords:
# --> 121                 return getattr(self, 'parse_' + self.stream.current.value)()
#     122             if token.value == 'call':
#     123                 return self.parse_call_block()
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_for(self)
#     182         self.stream.expect('name:in')
#     183         iter = self.parse_tuple(with_condexpr=False,
# --> 184                                 extra_end_rules=('name:recursive',))
#     185         test = None
#     186         if self.stream.skip_if('name:if'):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_tuple(self, simplified, with_condexpr, extra_end_rules, explicit_parentheses)
#     614             if self.is_tuple_end(extra_end_rules):
#     615                 break
# --> 616             args.append(parse())
#     617             if self.stream.current.type == 'comma':
#     618                 is_tuple = True
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in <lambda>()
#     606             parse = self.parse_expression
#     607         else:
# --> 608             parse = lambda: self.parse_expression(with_condexpr=False)
#     609         args = []
#     610         is_tuple = False
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_expression(self, with_condexpr)
#     389         if with_condexpr:
#     390             return self.parse_condexpr()
# --> 391         return self.parse_or()
#     392
#     393     def parse_condexpr(self):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_or(self)
#     406     def parse_or(self):
#     407         lineno = self.stream.current.lineno
# --> 408         left = self.parse_and()
#     409         while self.stream.skip_if('name:or'):
#     410             right = self.parse_and()
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_and(self)
#     415     def parse_and(self):
#     416         lineno = self.stream.current.lineno
# --> 417         left = self.parse_not()
#     418         while self.stream.skip_if('name:and'):
#     419             right = self.parse_not()
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_not(self)
#     426             lineno = next(self.stream).lineno
#     427             return nodes.Not(self.parse_not(), lineno=lineno)
# --> 428         return self.parse_compare()
#     429
#     430     def parse_compare(self):
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_compare(self)
#     430     def parse_compare(self):
#     431         lineno = self.stream.current.lineno
# --> 432         expr = self.parse_add()
#     433         ops = []
#     434         while 1:
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_add(self)
#     452     def parse_add(self):
#     453         lineno = self.stream.current.lineno
# --> 454         left = self.parse_sub()
#     455         while self.stream.current.type == 'add':
#     456             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_sub(self)
#     462     def parse_sub(self):
#     463         lineno = self.stream.current.lineno
# --> 464         left = self.parse_concat()
#     465         while self.stream.current.type == 'sub':
#     466             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_concat(self)
#     472     def parse_concat(self):
#     473         lineno = self.stream.current.lineno
# --> 474         args = [self.parse_mul()]
#     475         while self.stream.current.type == 'tilde':
#     476             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_mul(self)
#     482     def parse_mul(self):
#     483         lineno = self.stream.current.lineno
# --> 484         left = self.parse_div()
#     485         while self.stream.current.type == 'mul':
#     486             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_div(self)
#     492     def parse_div(self):
#     493         lineno = self.stream.current.lineno
# --> 494         left = self.parse_floordiv()
#     495         while self.stream.current.type == 'div':
#     496             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_floordiv(self)
#     502     def parse_floordiv(self):
#     503         lineno = self.stream.current.lineno
# --> 504         left = self.parse_mod()
#     505         while self.stream.current.type == 'floordiv':
#     506             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_mod(self)
#     512     def parse_mod(self):
#     513         lineno = self.stream.current.lineno
# --> 514         left = self.parse_pow()
#     515         while self.stream.current.type == 'mod':
#     516             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_pow(self)
#     522     def parse_pow(self):
#     523         lineno = self.stream.current.lineno
# --> 524         left = self.parse_unary()
#     525         while self.stream.current.type == 'pow':
#     526             next(self.stream)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_unary(self, with_filter)
#     541         else:
#     542             node = self.parse_primary()
# --> 543         node = self.parse_postfix(node)
#     544         if with_filter:
#     545             node = self.parse_filter_expr(node)
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_postfix(self, node)
#     666             token_type = self.stream.current.type
#     667             if token_type == 'dot' or token_type == 'lbracket':
# --> 668                 node = self.parse_subscript(node)
#     669             # calls are valid both after postfix expressions (getattr
#     670             # and getitem) as well as filters and tests
#
# /opt/conda/lib/python2.7/site-packages/jinja2/parser.pyc in parse_subscript(self, node)
#     694         if token.type == 'dot':
#     695             attr_token = self.stream.current
# --> 696             next(self.stream)
#     697             if attr_token.type == 'name':
#     698                 return nodes.Getattr(node, attr_token.value, 'load',
#
# /opt/conda/lib/python2.7/site-packages/jinja2/lexer.pyc in __next__(self)
#     347         elif self.current.type is not TOKEN_EOF:
#     348             try:
# --> 349                 self.current = next(self._iter)
#     350             except StopIteration:
#     351                 self.close()
#
# /opt/conda/lib/python2.7/site-packages/jinja2/lexer.pyc in wrap(self, stream, name, filename)
#     550         every token in a :class:`Token` and converts the value.
#     551         """
# --> 552         for lineno, token, value in stream:
#     553             if token in ignored_tokens:
#     554                 continue
#
# /opt/conda/lib/python2.7/site-packages/jinja2/lexer.pyc in tokeniter(self, source, name, filename, state)
#     687                     if data or tokens not in ignore_if_empty:
#     688                         yield lineno, tokens, data
# --> 689                     lineno += data.count('\n')
#     690
#     691                 # fetch new position into new variable so that we can check
#
# KeyboardInterrupt:

# %%
map1.save('../Maps/subway_stops.html')

# %% [markdown]
# The second plot shows all the transfer stations as the larger squares on the map.

# %%
transfers = pd.read_csv('../Data/transfers_updated.txt',usecols=['from_stop_id','to_stop_id'])

# %%
transfers = transfers[transfers['from_stop_id']!=transfers['to_stop_id']]
from_stations = transfers.groupby('from_stop_id').size().index
to_stations = transfers.groupby('to_stop_id').size().index
transfer_stations = set(from_stations.append(to_stations))

# %%
map2 = folium.Map(location=[40.7528, -73.92],zoom_start=12,tiles='Stamen Terrain')

for i in xrange(len(ploting_data)):
    if ploting_data.loc[i]['parent_station'] in transfer_stations:
        size=10
    else:
        size=2
    folium.RegularPolygonMarker(location=[ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']], 
                                popup=ploting_data.loc[i]['stop_name'],number_of_sides=4, radius=size,
                                color=colors[ploting_data.loc[i]['route_dir_id']],
                                fill_color=colors[ploting_data.loc[i]['route_dir_id']]).add_to(map2)
for i in xrange(len(ploting_data)-1):
    if ploting_data.loc[i]['route_dir_id']==ploting_data.loc[i+1]['route_dir_id'] and ploting_data.loc[i]['stop_sequence']==ploting_data.loc[i+1]['stop_sequence']-1:
        folium.PolyLine([(ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']),
                         (ploting_data.loc[i+1]['stop_lat'],ploting_data.loc[i+1]['stop_lon'])],
                        opacity=1,color=colors[ploting_data.loc[i]['route_dir_id']],weight=2).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map2.save('../Maps/transfer_stations.html')

# %% [markdown]
# Finally, I plot the popularity of the different transfer stations, by changing the size of the markers. I scaled the popularities by the number of train lines that come to that station. Before this scaling Times Square was the most popular transfer point, because almost every train line stops there. After scaling, we can see that 59th St - Columbus Circle is also just as popular as Times Square.

# %%
import datetime
def sec_to_time(row):
    hour = row['seconds'] // 3600
    minute = (row['seconds'] - hour*3600) / 60
    return datetime.time(int(hour), int(minute), 0)

# %%
data = pd.read_csv('../Data/Crowdedness/trip_data_crowdedness.csv', usecols=['stop_id','day','adjusted_value','seconds'])
data['time'] = data.apply(sec_to_time, axis=1)
stops = pd.read_csv('../Data/stops_updated.txt',usecols=['stop_id','stop_name','stop_lat','stop_lon','lines'])
stops['lines'] = stops['lines'].apply(literal_eval)
data_new = data.merge(stops, on='stop_id')
data_json = data_new.to_json(orient='records')
with open('../Data/Crowdedness/crowdedness.json', 'w') as f:
    f.write(data_json)

# %%
data = pd.read_csv('../Data/Crowdedness/trip_data_crowdedness.csv', usecols=['stop_id','day','adjusted_value','seconds'])
data = data[(data['stop_id'].isin(['125','132','116'])) & (data['day'] == 'Weekday')]
data['time'] = data.apply(sec_to_time, axis=1)
stops = pd.read_csv('../Data/stops_updated.txt',usecols=['stop_id','stop_name','stop_lat','stop_lon','lines'])
stops['lines'] = stops['lines'].apply(literal_eval)
data_new = data.merge(stops, on='stop_id')
data_json = data_new.to_json(orient='records')
with open('../Data/Crowdedness/sample_crowdedness.json', 'w') as f:
    f.write(data_json)

# %%
data_new['hour'] = data_new.apply(lambda x: x['time'].hour, axis=1)

# %%
data_new.head()
# Out:
#   stop_id       day  adjusted_value  seconds      time stop_name   stop_lat  \
# 0     103    Sunday             5.0    13200  03:40:00    238 St  40.884667
# 1     103   Weekday             1.0    30000  08:20:00    238 St  40.884667
# 2     103  Saturday             2.0     3000  00:50:00    238 St  40.884667
# 3     103  Saturday             1.0     6000  01:40:00    238 St  40.884667
# 4     103  Saturday            15.0     6600  01:50:00    238 St  40.884667
#
#    stop_lon lines  hour
# 0 -73.90087   [1]     3
# 1 -73.90087   [1]     8
# 2 -73.90087   [1]     0
# 3 -73.90087   [1]     1
# 4 -73.90087   [1]     1

# %%
group = pd.DataFrame(data_new.groupby(['stop_id','day','hour'])['adjusted_value'].sum()).reset_index()
group[(group.stop_id == '101') & (group.day == 'Weekday')]
# Out:
#    stop_id      day  hour  adjusted_value
# 14     101  Weekday     0             1.0
# 15     101  Weekday     1             7.0
# 16     101  Weekday     2             1.0
# 17     101  Weekday     3             2.0
# 18     101  Weekday     7             1.0
# 19     101  Weekday     9             3.0
# 20     101  Weekday    10             3.0
# 21     101  Weekday    11             1.0
# 22     101  Weekday    13             1.0
# 23     101  Weekday    15             2.0
# 24     101  Weekday    18             1.0
# 25     101  Weekday    19             3.0
# 26     101  Weekday    21             4.0
# 27     101  Weekday    22             6.0
# 28     101  Weekday    23             3.0

# %%
crowdedness = pd.read_csv('../Data/Crowdedness/trip_data_crowdedness.csv')#,usecols=['stop_id_start_transfer','stop_id_end_transfer','popularity'])
crowdedness = crowdedness.groupby('stop_id')['adjusted_value'].sum()

# %%
crowdedness = pd.DataFrame(crowdedness)

# %%
crowdedness['scaled_value'] = crowdedness['adjusted_value']/max(crowdedness['adjusted_value'])

# %%
crowdedness
# Out:
#          adjusted_value  scaled_value
# stop_id
# 101           73.000000      0.000223
# 103          134.000000      0.000409
# 104          202.000000      0.000616
# 106          127.000000      0.000387
# 107          311.000000      0.000949
# 108          211.000000      0.000644
# 109          396.000000      0.001208
# 110          564.000000      0.001721
# 111         1219.000000      0.003719
# 112        19901.333333      0.060713
# 113         2218.000000      0.006766
# 114         3129.000000      0.009546
# 115         3914.000000      0.011940
# 116         5071.000000      0.015470
# 117        14411.000000      0.043964
# 118        14389.000000      0.043897
# 119        16806.000000      0.051270
# 120        27260.166667      0.083163
# 121        36054.000000      0.109990
# 122        39358.000000      0.120070
# 123        40419.500000      0.123308
# 124        64269.000000      0.196066
# 125       200861.833333      0.612772
# 126        20606.000000      0.062863
# 127       327792.194444      1.000000
# 128        57580.916667      0.175663
# 129        36280.000000      0.110680
# 130        19224.000000      0.058647
# 131        17777.000000      0.054233
# 132       121537.416667      0.370776
# ...                 ...           ...
# R17        64070.881702      0.195462
# R18        42536.400932      0.129766
# R19        38754.400932      0.118229
# R20        88311.317599      0.269413
# R21        28487.900932      0.086908
# R22        31586.400932      0.096361
# R23        32590.647436      0.099425
# R24         8646.000000      0.026376
# R25         8610.000000      0.026267
# R26         2728.000000      0.008322
# R27        40391.333333      0.123222
# R28        14124.500000      0.043090
# R29        23615.166667      0.072043
# R30        13054.750000      0.039826
# R31        20744.250000      0.063285
# R32         6201.000000      0.018917
# R33         8619.666667      0.026296
# R34         2535.000000      0.007734
# R35          857.000000      0.002614
# R36          952.333333      0.002905
# R39          428.000000      0.001306
# R40          318.000000      0.000970
# R41          271.000000      0.000827
# R42          431.000000      0.001315
# R43          587.000000      0.001791
# R44          535.000000      0.001632
# R45          522.000000      0.001592
# S01          614.000000      0.001873
# S03          751.000000      0.002291
# S04          766.166667      0.002337
#
# [443 rows x 2 columns]

# %%
def num_lines(row):
    return len(row['lines'])
    
stops['num_of_lines'] = stops.apply(num_lines,axis=1)

# %%
popularity = popularity.merge(parent_stops[['stop_id','num_of_lines']],left_on='stop_id_start_transfer',right_on='stop_id').merge(parent_stops[['stop_id','num_of_lines']],left_on='stop_id_end_transfer',right_on='stop_id')

# %%
start_popularity = pd.DataFrame(popularity.groupby('stop_id_start_transfer')['popularity'].sum()).reset_index()#,columns=['popularity_start'])
start_popularity = start_popularity.merge(parent_stops[['stop_id','num_of_lines']],left_on='stop_id_start_transfer',right_on='stop_id')
end_popularity = pd.DataFrame(popularity.groupby('stop_id_end_transfer')['popularity'].sum()).reset_index()#,columns=['popularity_end'])
end_popularity = end_popularity.merge(parent_stops[['stop_id','num_of_lines']],left_on='stop_id_end_transfer',right_on='stop_id')
total_popularity = start_popularity.merge(end_popularity, on=['stop_id','num_of_lines'])

# %%
total_popularity.head()
# Out:
#         stop_id_start_transfer  popularity_x  num_of_lines  \
# stop_id
# 112                        112      0.096389             1
# 120                        120      0.063825             3
# 123                        123      0.025497             3
# 125                        125      0.718922             1
# 127                        127      2.208676             3
#
#         stop_id_end_transfer  popularity_y  popularity
# stop_id
# 112                      112      0.087409    0.183798
# 120                      120      0.063825    0.042550
# 123                      123      0.025497    0.016998
# 125                      125      0.776767    1.495689
# 127                      127      2.237051    1.481909

# %%
total_popularity['popularity'] = (total_popularity['popularity_x'] + total_popularity['popularity_y'])/total_popularity['num_of_lines']
total_popularity = total_popularity.set_index('stop_id')#.max()

# %%
map3 = folium.Map(location=[40.7528, -73.92],zoom_start=12,tiles='Stamen Terrain')

for i in xrange(len(ploting_data)):
    if ploting_data.loc[i]['parent_station'] in crowdedness.index:
        size = 20*crowdedness.loc[ploting_data.loc[i]['parent_station']]['scaled_value']
        folium.RegularPolygonMarker(location=[ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']], 
                                    popup=ploting_data.loc[i]['stop_name'],number_of_sides=4, radius=size,
                                    color=None,
                                    fill_color=colors[ploting_data.loc[i]['route_dir_id']],fill_opacity=0.8).add_to(map3)

for i in xrange(len(ploting_data)-1):
    if ploting_data.loc[i]['route_dir_id']==ploting_data.loc[i+1]['route_dir_id'] and ploting_data.loc[i]['stop_sequence']==ploting_data.loc[i+1]['stop_sequence']-1:
        folium.PolyLine([(ploting_data.loc[i]['stop_lat'],ploting_data.loc[i]['stop_lon']),
                         (ploting_data.loc[i+1]['stop_lat'],ploting_data.loc[i+1]['stop_lon'])],
                        opacity=1,color=colors[ploting_data.loc[i]['route_dir_id']],weight=2).add_to(map3)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map3.save('../Maps/subway_crowdedness.html')
