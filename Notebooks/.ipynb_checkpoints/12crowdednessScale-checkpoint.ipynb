# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 144

# %%
df = pd.read_csv('../Data/Crowdedness/trip_data_crowdedness_new.csv',usecols=['stop_id','seconds','day','adjusted_value'])

# %% [markdown]
# # Picking Scale of Crowdedness Value (1-10)
#
# Looking at the histogram of crowdedness values, we can see that the data is highly skewed towards low values due to the number of stations with very little taxi data. To correct for that, I am using a log scale to divide my 10 groups of crowdedness values.

# %%
def custom_bins(row):
    space = np.logspace(0,2.65,9)
    return bisect(space,row['adjusted_value'])+1

df['bin'] = df.apply(custom_bins,axis=1)

# %%
df_bin = df[['seconds','bin']].set_index('seconds')
df_hist = df[['seconds','adjusted_value']].set_index('seconds')

# %%
space = np.logspace(0,2.65,9)
df_hist.plot(kind='hist', bins=30)
for div in space:
    plt.plot([div,div],[0,10000],'--')
plt.ylim(0,10000)
# Out:
# (0, 10000)

# %%
df_bin.plot(kind='hist')
